# %%
import mysql.connector as mysql

# %%
db = mysql.connect(
    host='localhost',
    user='root',
    passwd='1234',
    database='poooooo'

)

# %%
mycursor.execute('show databases')
for i in mycursor:
    print(i)
# Out:
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('pooooo',)
# ('poooooid',)
# ('poooooo',)
# ('sakila',)
# ('sys',)
# ('world',)

# %%
mycursor=db.cursor()

# %%
mycursor.execute("create database task ")

# %%
mycursor.execute("create table pootoooo(item_identifire char(50),item_weight double,item_visibility double)")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     512                 query = query.encode('utf-8')
# --> 513             self._cmysql.query(query,
#     514                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Table 'pootoooo' already exists
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-9-8c00876f94d1> in <module>
# ----> 1 mycursor.execute("create table pootoooo(item_identifire char(50),item_weight double,item_visibility double)")
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     267
#     268         try:
# ...

# %%
mycursor=db.cursor()

# %%
mycursor.execute("CREATE TABLE general_info (id int PRIMARY KEY,name VARCHAR(255),company_name VARCHAR(255), salary double, work_location VARCHAR(255))")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     512                 query = query.encode('utf-8')
# --> 513             self._cmysql.query(query,
#     514                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Table 'general_info' already exists
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-22-2b104f708be8> in <module>
# ----> 1 mycursor.execute("CREATE TABLE general_info (id int PRIMARY KEY,name VARCHAR(255),company_name VARCHAR(255), salary double, work_location VARCHAR(255))")
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     267
# ...

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
    user = "root",
    passwd = "1234",
  database='task'
)

mycursor = mydb.cursor()

sql = "INSERT INTO customers (name, address) VALUES ('Mohamed-ElhajAbdou', 'Alexandria/egypt')"
mycursor.execute(sql)

mydb.commit()

print(mycursor.rowcount, "record inserted.")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     512                 query = query.encode('utf-8')
# --> 513             self._cmysql.query(query,
#     514                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Table 'task.customers' doesn't exist
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-29-a0fa48d3342c> in <module>
#      11
#      12 sql = "INSERT INTO customers (name, address) VALUES ('Mohamed-ElhajAbdou', 'Alexandria/egypt')"
# ---> 13 mycursor.execute(sql)
#      14
#      15 mydb.commit()
#
# ...

# %%
pip install mysqlclient
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
import pandas as pd
pd.options.display.max_rows = 10000
pd.options.display.max_columns = 10000
import matplotlib.pyplot as plt
import numpy as np 
import seaborn

# %%
db_connection_str = 'mysql://root:1234@localhost/poooooo'
db_connection = create_engine(db_connection_str)

# %%
df = pd.read_sql('SELECT * FROM id dataset', con=db_connection)
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1704                 if not evt_handled:
# -> 1705                     self.dialect.do_execute(
#    1706                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     691     def do_execute(self, cursor, statement, parameters, context=None):
# --> 692         cursor.execute(statement, parameters)
#     693
#
# ~\anaconda3\lib\site-packages\MySQLdb\cursors.py in execute(self, query, args)
#     205         assert isinstance(query, (bytes, bytearray))
# --> 206         res = self._query(query)
#     207         return res
#
# ...
